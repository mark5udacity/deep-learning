# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like machine translation.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with words in text, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The matrix multiplication going into the first hidden layer will have almost all of the resulting values be zero. This a huge waste of computation.
#
# ![one-hot encodings](assets/one_hot_encoding.png)
#
# To solve this problem and greatly increase the efficiency of our networks, we use what are called embeddings. Embeddings are just a fully connected layer like you've seen before. We call this layer the embedding layer and the weights are embedding weights. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# ![lookup](assets/lookup_matrix.png)
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is called an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# <img src='assets/tokenize_lookup.png' width=500>
#
# There is nothing magical going on here. The embedding lookup table is just a weight matrix. The embedding layer is just a hidden layer. The lookup is just a shortcut for the matrix multiplication. The lookup table is trained just like any weight matrix as well.
#
# Embeddings aren't only used for words of course. You can use them for any model where you have a massive number of classes. A particular type of model called **Word2Vec** uses the embedding layer to find vector representations of words that contain semantic meaning.

# %% [markdown]
# ## Word2Vec
#
# The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

from collections import Counter
import random

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()
# Out:
# Text8 Dataset: 31.4MB [00:18, 1.68MB/s]

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
word_set = set(words)
print("Unique words: {}".format(len(word_set)))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to convert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %%
print(vocab_to_int['hello'])
print(int_to_vocab[6436])
print('\n-----')
print(int_words[-10:])
print([int_to_vocab[word] for word in int_words[-10:]])
print('\n-----')
print(words[:30])
print()
print(int_words[:30])
print([int_to_vocab[word] for word in int_words[:30]])
# Out:
# 6436
# hello
#
# -----
# [4, 3, 8, 21, 16, 3, 8, 21, 15, 72]
# ['in', 'one', 'nine', 'six', 'three', 'one', 'nine', 'six', 'five', 'b']
#
# -----
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']
#
# [5233, 3081, 11, 5, 194, 1, 3133, 45, 58, 155, 127, 741, 476, 10637, 133, 0, 27717, 1, 0, 102, 854, 2, 0, 15073, 63316, 1, 0, 150, 854, 3584]
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
threshold = 1e-5

word_probs = {}

# Use counter instead of hand-rolled
#for word in word_set:
#    word_probs[word] = 0

#for word in words:
#    word_probs[word] += 1

total_count = len(words)

for word, count in Counter(words).items():
    if count != 0:
        word_probs[word] = 1. - np.sqrt(threshold / (count / total_count))


print(word_probs['hello'])
print(word_probs['unter'])
print(word_probs['the'])
# Out:
# 0.152066431725
# -2.89412132696
# 0.987463765777

# %%
# From provided solution, I didn't think - numbers were allowed, but apparently, ok!

threshold = 1e-5
word_counts = Counter(int_words)
total_count = len(int_words)
freqs = {word: count/total_count for word, count in word_counts.items()}
p_drop = {word: 1 - np.sqrt(threshold/freqs[word]) for word in word_counts}
train_words = [word for word in int_words if random.random() < (1 - p_drop[word])]


print(p_drop[vocab_to_int['hello']])
print(p_drop[vocab_to_int['unter']])
print(p_drop[vocab_to_int['the']])
# Out:
# 0.152066431725
# -2.89412132696
# 0.987463765777

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size = 5):
    ''' Get a list of words in a window around an index. '''
    r = random.randint(1, window_size)
    start_idx = idx - r if idx - r >= window_size else 0
    end_idx = idx + r + 1
    return list(set(words[start_idx:idx] + words[idx + 1:end_idx + 1]))

# %%
random.randint(1,2) # randint is inclusive...so discussed solution is incorrect
# Out:
# 2

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words) // batch_size
    
    # only full batches
    words = words[:n_batches * batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx + batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x] * len(batch_y))
        yield x, y

# %%
#batch_gen = get_batches(words, 10)

print(next(batch_gen))
print(next(batch_gen)[1])
print(next(batch_gen)[1][2])

#del batch_gen
# Out:
# (['to', 'to', 'to', 'to', 'use', 'use', 'use', 'use', 'use', 'the', 'the', 'the', 'the', 'the', 'the', 'term', 'term', 'term', 'term', 'term', 'term', 'term', 'to', 'to', 'to', 'to', 'to', 'to', 'to', 'to', 'to', 'mean', 'mean', 'mean', 'mean', 'mean', 'mean', 'mean', 'mean', 'something', 'something', 'something', 'something', 'something', 'something', 'something', 'something', 'other', 'other', 'other', 'other', 'other', 'other', 'other', 'other', 'than', 'than', 'chaos', 'chaos', 'chaos', 'chaos', 'chaos', 'chaos', 'chaos', 'chaos'], ['term', 'use', 'to', 'the', 'to', 'term', 'something', 'the', 'mean', 'other', 'term', 'something', 'to', 'use', 'mean', 'than', 'the', 'other', 'something', 'to', 'use', 'mean', 'than', 'chaos', 'the', 'other', 'term', 'something', 'to', 'use', 'mean', 'than', 'the', 'other', 'term', 'something', 'to', 'use', 'chaos', 'than', 'chaos', 'the', 'other', 'term', 'to', 'use', 'mean', 'than', 'chaos', 'the', 'term', 'something', 'to', 'use', 'mean', 'other', 'chaos', 'than', 'the', 'other', 'term', 'something', 'to', 'use', 'mean'])
# ['nouveaux', 'his', 'de', 'armand', 'in', 'baron', 'louis', 'nouveaux', 'voyages', 'his', 'armand', 'de', 'in', 'baron', 'was', 'his', 'de', 'in', 'baron', 'was', 'louis', 'nouveaux', 'his', 'armand', 'de', 'in', 'was', 'louis', 'nouveaux', 'voyages', 'dans', 'his', 'armand', 'in', 'baron', 'was', 'louis', 'nouveaux', 'voyages', 'dans', 'de', 'armand', 'his', 'baron', 'was', 'louis', 'voyages', 'nouveaux', 'in', 'voyages', 'dans', 'de', 'armand', 'in', 'his', 'baron', 'was', 'louis', 'nouveaux', 'dans', 'de', 'armand', 'in', 'his', 'baron', 'was', 'louis', 'nouveaux', 'voyages']
# rique

# %% [markdown]
# ## Building the graph
#
# From [Chris McCormick's blog](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/), we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as integers. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32
sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 4.0543 0.4363 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 4.0426 0.5566 sec/batch
# Nearest to had: dtt, appice, mole, radionuclides, ra, splits, wd, bouldering,
# Nearest to states: aesthetic, xxxxx, forfeit, quaternions, kalmykia, consortium, attorney, cringely,
# Nearest to during: serum, opanal, caravans, manifestly, literati, certified, edwina, purim,
# Nearest to were: neologism, dolphins, gpcrs, differ, entirely, keanu, fashion, presidium,
# Nearest to such: barbican, hydrosphere, fellin, cadavers, executives, pope, pathologies, incongruous,
# Nearest to be: freefall, peaches, embarrassed, vouli, alexandra, alai, macedonian, heaviest,
# Nearest to seven: jornal, store, sowing, licence, oktoberfest, ellison, berwick, vj,
# Nearest to it: dodi, described, flannery, checklist, dedham, terre, journal, ist,
# Nearest to woman: vermont, musk, mohel, lamenting, hurling, razzie, rivera, skins,
# Nearest to dr: haitham, domini, hydrography, whatever, chernobyl, turing, consultations, muluzi,
# Nearest to older: ricimer, calderas, amazon, disintegration, daydream, ld, corda, abunda,
# Nearest to placed: unicorns, geocaching, quincy, indulged, descending, chemically, dangerous, speaker,
# Nearest to arts: hif, saintly, roderick, button, beating, acknowledging, kamikaze, enactments,
# Nearest to alternative: swept, mellotron, forgetting, lzw, scooby, sci, kemerovo, spike,
# Nearest to smith: downrock, clutter, olissipo, advisor, odos, pheasants, wants, iix,
# Nearest to shown: sampled, tetralogy, dreamy, varied, senussi, unaids, basenjis, fairies,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 4.0039 0.6313 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 4.0361 0.6205 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 4.0370 0.7008 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 4.0461 0.6668 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 4.0890 0.6755 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 4.0554 0.6028 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 4.0155 0.6708 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 3.9770 0.6479 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 4.0186 0.7414 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 3.9518 0.6741 sec/batch
# Nearest to had: dtt, appice, mole, radionuclides, ra, splits, wd, bouldering,
# Nearest to states: aesthetic, xxxxx, forfeit, quaternions, kalmykia, consortium, attorney, cringely,
# Nearest to during: serum, opanal, caravans, manifestly, literati, certified, edwina, purim,
# Nearest to were: neologism, dolphins, gpcrs, differ, entirely, keanu, fashion, presidium,
# Nearest to such: barbican, hydrosphere, fellin, cadavers, executives, pope, pathologies, incongruous,
# Nearest to be: freefall, peaches, embarrassed, vouli, alexandra, alai, macedonian, heaviest,
# Nearest to seven: jornal, store, sowing, licence, oktoberfest, ellison, berwick, vj,
# Nearest to it: dodi, described, flannery, checklist, dedham, terre, journal, ist,
# Nearest to woman: vermont, musk, mohel, lamenting, hurling, razzie, rivera, skins,
# Nearest to dr: haitham, domini, hydrography, whatever, chernobyl, turing, consultations, muluzi,
# Nearest to older: ricimer, calderas, amazon, disintegration, daydream, ld, corda, abunda,
# Nearest to placed: unicorns, geocaching, quincy, indulged, descending, chemically, dangerous, speaker,
# Nearest to arts: hif, saintly, roderick, button, beating, acknowledging, kamikaze, enactments,
# Nearest to alternative: swept, mellotron, forgetting, lzw, scooby, sci, kemerovo, spike,
# Nearest to smith: downrock, clutter, olissipo, advisor, odos, pheasants, wants, iix,
# Nearest to shown: sampled, tetralogy, dreamy, varied, senussi, unaids, basenjis, fairies,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 4.0066 0.6613 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 3.9454 0.6525 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 4.0256 0.6746 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 4.0032 0.5991 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 4.0298 13.7841 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 4.0294 2.8225 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 3.9029 2.6614 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 3.9614 3.7800 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 3.9528 0.7116 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 3.9774 0.6242 sec/batch
# Nearest to had: dtt, appice, mole, radionuclides, ra, splits, wd, bouldering,
# Nearest to states: aesthetic, xxxxx, forfeit, quaternions, kalmykia, consortium, attorney, cringely,
# Nearest to during: serum, opanal, caravans, manifestly, literati, certified, edwina, purim,
# Nearest to were: neologism, dolphins, gpcrs, differ, entirely, keanu, fashion, presidium,
# Nearest to such: barbican, hydrosphere, fellin, cadavers, executives, pope, pathologies, incongruous,
# Nearest to be: freefall, peaches, embarrassed, vouli, alexandra, alai, macedonian, heaviest,
# Nearest to seven: jornal, store, sowing, licence, oktoberfest, ellison, berwick, vj,
# Nearest to it: dodi, described, flannery, checklist, dedham, terre, journal, ist,
# Nearest to woman: vermont, musk, mohel, lamenting, hurling, razzie, rivera, skins,
# Nearest to dr: haitham, domini, hydrography, whatever, chernobyl, turing, consultations, muluzi,
# Nearest to older: ricimer, calderas, amazon, disintegration, daydream, ld, corda, abunda,
# Nearest to placed: unicorns, geocaching, quincy, indulged, descending, chemically, dangerous, speaker,
# Nearest to arts: hif, saintly, roderick, button, beating, acknowledging, kamikaze, enactments,
# Nearest to alternative: swept, mellotron, forgetting, lzw, scooby, sci, kemerovo, spike,
# Nearest to smith: downrock, clutter, olissipo, advisor, odos, pheasants, wants, iix,
# Nearest to shown: sampled, tetralogy, dreamy, varied, senussi, unaids, basenjis, fairies,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 3.9943 0.5933 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 4.0057 0.4959 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 3.9740 0.4878 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 4.0070 0.4718 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 4.0329 0.4547 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 3.9735 0.4701 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 3.9927 0.4500 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 4.0096 0.4439 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 4.0344 0.4345 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 4.0166 0.4518 sec/batch
# Nearest to had: dtt, appice, mole, radionuclides, ra, splits, wd, bouldering,
# Nearest to states: aesthetic, xxxxx, forfeit, quaternions, kalmykia, consortium, attorney, cringely,
# Nearest to during: serum, opanal, caravans, manifestly, literati, certified, edwina, purim,
# Nearest to were: neologism, dolphins, gpcrs, differ, entirely, keanu, fashion, presidium,
# Nearest to such: barbican, hydrosphere, fellin, cadavers, executives, pope, pathologies, incongruous,
# Nearest to be: freefall, peaches, embarrassed, vouli, alexandra, alai, macedonian, heaviest,
# Nearest to seven: jornal, store, sowing, licence, oktoberfest, ellison, berwick, vj,
# Nearest to it: dodi, described, flannery, checklist, dedham, terre, journal, ist,
# Nearest to woman: vermont, musk, mohel, lamenting, hurling, razzie, rivera, skins,
# Nearest to dr: haitham, domini, hydrography, whatever, chernobyl, turing, consultations, muluzi,
# Nearest to older: ricimer, calderas, amazon, disintegration, daydream, ld, corda, abunda,
# Nearest to placed: unicorns, geocaching, quincy, indulged, descending, chemically, dangerous, speaker,
# Nearest to arts: hif, saintly, roderick, button, beating, acknowledging, kamikaze, enactments,
# Nearest to alternative: swept, mellotron, forgetting, lzw, scooby, sci, kemerovo, spike,
# Nearest to smith: downrock, clutter, olissipo, advisor, odos, pheasants, wants, iix,
# Nearest to shown: sampled, tetralogy, dreamy, varied, senussi, unaids, basenjis, fairies,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 4.0349 0.4991 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 3.9875 0.4385 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 4.0036 0.4466 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 4.0060 0.4797 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 4.0169 0.5203 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 4.0120 0.4660 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 3.9906 0.4586 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 3.9895 0.5132 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 3.9842 0.5270 sec/batch
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 4.0090 0.4576 sec/batch
# Nearest to had: dtt, appice, mole, radionuclides, ra, splits, wd, bouldering,
# Nearest to states: aesthetic, xxxxx, forfeit, quaternions, kalmykia, consortium, attorney, cringely,
# Nearest to during: serum, opanal, caravans, manifestly, literati, certified, edwina, purim,
# Nearest to were: neologism, dolphins, gpcrs, differ, entirely, keanu, fashion, presidium,
# Nearest to such: barbican, hydrosphere, fellin, cadavers, executives, pope, pathologies, incongruous,
# Nearest to be: freefall, peaches, embarrassed, vouli, alexandra, alai, macedonian, heaviest,
# Nearest to seven: jornal, store, sowing, licence, oktoberfest, ellison, berwick, vj,
# Nearest to it: dodi, described, flannery, checklist, dedham, terre, journal, ist,
# Nearest to woman: vermont, musk, mohel, lamenting, hurling, razzie, rivera, skins,
# Nearest to dr: haitham, domini, hydrography, whatever, chernobyl, turing, consultations, muluzi,
# Nearest to older: ricimer, calderas, amazon, disintegration, daydream, ld, corda, abunda,
# Nearest to placed: unicorns, geocaching, quincy, indulged, descending, chemically, dangerous, speaker,
# Nearest to arts: hif, saintly, roderick, button, beating, acknowledging, kamikaze, enactments,
# Nearest to alternative: swept, mellotron, forgetting, lzw, scooby, sci, kemerovo, spike,
# Nearest to smith: downrock, clutter, olissipo, advisor, odos, pheasants, wants, iix,
# Nearest to shown: sampled, tetralogy, dreamy, varied, senussi, unaids, basenjis, fairies,
# Epoch 5/10 Iteration: 22100 Avg. Training loss: 3.9577 0.5444 sec/batch
# Epoch 5/10 Iteration: 22200 Avg. Training loss: 4.1164 0.5355 sec/batch
# Epoch 5/10 Iteration: 22300 Avg. Training loss: 4.0390 0.4688 sec/batch
# ...
# Nearest to older: ricimer, calderas, amazon, disintegration, daydream, ld, corda, abunda,
# Nearest to placed: unicorns, geocaching, quincy, indulged, descending, chemically, dangerous, speaker,
# Nearest to arts: hif, saintly, roderick, button, beating, acknowledging, kamikaze, enactments,
# Nearest to alternative: swept, mellotron, forgetting, lzw, scooby, sci, kemerovo, spike,
# Nearest to smith: downrock, clutter, olissipo, advisor, odos, pheasants, wants, iix,
# Nearest to shown: sampled, tetralogy, dreamy, varied, senussi, unaids, basenjis, fairies,
# Epoch 9/10 Iteration: 39100 Avg. Training loss: 3.8485 0.4279 sec/batch
# Epoch 9/10 Iteration: 39200 Avg. Training loss: 3.8642 0.4021 sec/batch
# Epoch 9/10 Iteration: 39300 Avg. Training loss: 3.8585 0.4256 sec/batch
# Epoch 9/10 Iteration: 39400 Avg. Training loss: 3.8440 0.3998 sec/batch
# Epoch 9/10 Iteration: 39500 Avg. Training loss: 3.8956 0.4046 sec/batch
# Epoch 9/10 Iteration: 39600 Avg. Training loss: 3.9276 0.4124 sec/batch
# Epoch 9/10 Iteration: 39700 Avg. Training loss: 3.8850 0.4014 sec/batch
# Epoch 9/10 Iteration: 39800 Avg. Training loss: 3.8604 0.4013 sec/batch
# Epoch 9/10 Iteration: 39900 Avg. Training loss: 3.9092 0.4028 sec/batch
# Epoch 9/10 Iteration: 40000 Avg. Training loss: 3.8793 0.4275 sec/batch
# Nearest to had: dtt, appice, mole, radionuclides, ra, splits, wd, bouldering,
# Nearest to states: aesthetic, xxxxx, forfeit, quaternions, kalmykia, consortium, attorney, cringely,
# Nearest to during: serum, opanal, caravans, manifestly, literati, certified, edwina, purim,
# Nearest to were: neologism, dolphins, gpcrs, differ, entirely, keanu, fashion, presidium,
# Nearest to such: barbican, hydrosphere, fellin, cadavers, executives, pope, pathologies, incongruous,
# Nearest to be: freefall, peaches, embarrassed, vouli, alexandra, alai, macedonian, heaviest,
# Nearest to seven: jornal, store, sowing, licence, oktoberfest, ellison, berwick, vj,
# Nearest to it: dodi, described, flannery, checklist, dedham, terre, journal, ist,
# Nearest to woman: vermont, musk, mohel, lamenting, hurling, razzie, rivera, skins,
# Nearest to dr: haitham, domini, hydrography, whatever, chernobyl, turing, consultations, muluzi,
# Nearest to older: ricimer, calderas, amazon, disintegration, daydream, ld, corda, abunda,
# Nearest to placed: unicorns, geocaching, quincy, indulged, descending, chemically, dangerous, speaker,
# Nearest to arts: hif, saintly, roderick, button, beating, acknowledging, kamikaze, enactments,
# Nearest to alternative: swept, mellotron, forgetting, lzw, scooby, sci, kemerovo, spike,
# Nearest to smith: downrock, clutter, olissipo, advisor, odos, pheasants, wants, iix,
# Nearest to shown: sampled, tetralogy, dreamy, varied, senussi, unaids, basenjis, fairies,
# Epoch 9/10 Iteration: 40100 Avg. Training loss: 3.8756 0.7343 sec/batch
# Epoch 9/10 Iteration: 40200 Avg. Training loss: 3.8642 0.4952 sec/batch
# Epoch 9/10 Iteration: 40300 Avg. Training loss: 3.8624 0.4373 sec/batch
# Epoch 9/10 Iteration: 40400 Avg. Training loss: 3.8491 0.4303 sec/batch
# Epoch 9/10 Iteration: 40500 Avg. Training loss: 3.8838 0.4380 sec/batch
# Epoch 9/10 Iteration: 40600 Avg. Training loss: 3.8705 0.4325 sec/batch
# Epoch 9/10 Iteration: 40700 Avg. Training loss: 3.9791 0.4531 sec/batch
# Epoch 9/10 Iteration: 40800 Avg. Training loss: 3.9293 0.4119 sec/batch
# Epoch 9/10 Iteration: 40900 Avg. Training loss: 3.9209 0.4035 sec/batch
# Epoch 9/10 Iteration: 41000 Avg. Training loss: 3.8294 0.4123 sec/batch
# Nearest to had: dtt, appice, mole, radionuclides, ra, splits, wd, bouldering,
# Nearest to states: aesthetic, xxxxx, forfeit, quaternions, kalmykia, consortium, attorney, cringely,
# Nearest to during: serum, opanal, caravans, manifestly, literati, certified, edwina, purim,
# Nearest to were: neologism, dolphins, gpcrs, differ, entirely, keanu, fashion, presidium,
# Nearest to such: barbican, hydrosphere, fellin, cadavers, executives, pope, pathologies, incongruous,
# Nearest to be: freefall, peaches, embarrassed, vouli, alexandra, alai, macedonian, heaviest,
# Nearest to seven: jornal, store, sowing, licence, oktoberfest, ellison, berwick, vj,
# Nearest to it: dodi, described, flannery, checklist, dedham, terre, journal, ist,
# Nearest to woman: vermont, musk, mohel, lamenting, hurling, razzie, rivera, skins,
# Nearest to dr: haitham, domini, hydrography, whatever, chernobyl, turing, consultations, muluzi,
# Nearest to older: ricimer, calderas, amazon, disintegration, daydream, ld, corda, abunda,
# Nearest to placed: unicorns, geocaching, quincy, indulged, descending, chemically, dangerous, speaker,
# Nearest to arts: hif, saintly, roderick, button, beating, acknowledging, kamikaze, enactments,
# Nearest to alternative: swept, mellotron, forgetting, lzw, scooby, sci, kemerovo, spike,
# Nearest to smith: downrock, clutter, olissipo, advisor, odos, pheasants, wants, iix,
# Nearest to shown: sampled, tetralogy, dreamy, varied, senussi, unaids, basenjis, fairies,
# Epoch 9/10 Iteration: 41100 Avg. Training loss: 3.8370 0.4665 sec/batch
# Epoch 9/10 Iteration: 41200 Avg. Training loss: 3.8716 0.4224 sec/batch
# Epoch 9/10 Iteration: 41300 Avg. Training loss: 3.7892 0.4350 sec/batch
# Epoch 9/10 Iteration: 41400 Avg. Training loss: 3.8856 0.4253 sec/batch
# Epoch 9/10 Iteration: 41500 Avg. Training loss: 3.8978 0.4225 sec/batch
# Epoch 9/10 Iteration: 41600 Avg. Training loss: 3.8768 0.4195 sec/batch
# Epoch 10/10 Iteration: 41700 Avg. Training loss: 3.9390 0.1689 sec/batch
# Epoch 10/10 Iteration: 41800 Avg. Training loss: 3.8246 0.3934 sec/batch
# Epoch 10/10 Iteration: 41900 Avg. Training loss: 3.8434 0.4106 sec/batch
# Epoch 10/10 Iteration: 42000 Avg. Training loss: 3.8305 0.4184 sec/batch
# Nearest to had: dtt, appice, mole, radionuclides, ra, splits, wd, bouldering,
# Nearest to states: aesthetic, xxxxx, forfeit, quaternions, kalmykia, consortium, attorney, cringely,
# Nearest to during: serum, opanal, caravans, manifestly, literati, certified, edwina, purim,
# Nearest to were: neologism, dolphins, gpcrs, differ, entirely, keanu, fashion, presidium,
# Nearest to such: barbican, hydrosphere, fellin, cadavers, executives, pope, pathologies, incongruous,
# Nearest to be: freefall, peaches, embarrassed, vouli, alexandra, alai, macedonian, heaviest,
# Nearest to seven: jornal, store, sowing, licence, oktoberfest, ellison, berwick, vj,
# Nearest to it: dodi, described, flannery, checklist, dedham, terre, journal, ist,
# Nearest to woman: vermont, musk, mohel, lamenting, hurling, razzie, rivera, skins,
# Nearest to dr: haitham, domini, hydrography, whatever, chernobyl, turing, consultations, muluzi,
# Nearest to older: ricimer, calderas, amazon, disintegration, daydream, ld, corda, abunda,
# Nearest to placed: unicorns, geocaching, quincy, indulged, descending, chemically, dangerous, speaker,
# Nearest to arts: hif, saintly, roderick, button, beating, acknowledging, kamikaze, enactments,
# Nearest to alternative: swept, mellotron, forgetting, lzw, scooby, sci, kemerovo, spike,
# Nearest to smith: downrock, clutter, olissipo, advisor, odos, pheasants, wants, iix,
# Nearest to shown: sampled, tetralogy, dreamy, varied, senussi, unaids, basenjis, fairies,
# Epoch 10/10 Iteration: 42100 Avg. Training loss: 3.8377 0.4232 sec/batch
# Epoch 10/10 Iteration: 42200 Avg. Training loss: 3.8383 0.4074 sec/batch
# Epoch 10/10 Iteration: 42300 Avg. Training loss: 3.8415 0.3897 sec/batch
# Epoch 10/10 Iteration: 42400 Avg. Training loss: 3.7982 0.4017 sec/batch
# Epoch 10/10 Iteration: 42500 Avg. Training loss: 3.8594 0.4044 sec/batch
# Epoch 10/10 Iteration: 42600 Avg. Training loss: 3.8499 0.4257 sec/batch
# Epoch 10/10 Iteration: 42700 Avg. Training loss: 3.8901 0.4047 sec/batch
# Epoch 10/10 Iteration: 42800 Avg. Training loss: 3.7619 0.4151 sec/batch
# Epoch 10/10 Iteration: 42900 Avg. Training loss: 3.8218 0.4162 sec/batch
# Epoch 10/10 Iteration: 43000 Avg. Training loss: 3.8323 0.4578 sec/batch
# Nearest to had: dtt, appice, mole, radionuclides, ra, splits, wd, bouldering,
# Nearest to states: aesthetic, xxxxx, forfeit, quaternions, kalmykia, consortium, attorney, cringely,
# Nearest to during: serum, opanal, caravans, manifestly, literati, certified, edwina, purim,
# Nearest to were: neologism, dolphins, gpcrs, differ, entirely, keanu, fashion, presidium,
# Nearest to such: barbican, hydrosphere, fellin, cadavers, executives, pope, pathologies, incongruous,
# Nearest to be: freefall, peaches, embarrassed, vouli, alexandra, alai, macedonian, heaviest,
# Nearest to seven: jornal, store, sowing, licence, oktoberfest, ellison, berwick, vj,
# Nearest to it: dodi, described, flannery, checklist, dedham, terre, journal, ist,
# Nearest to woman: vermont, musk, mohel, lamenting, hurling, razzie, rivera, skins,
# Nearest to dr: haitham, domini, hydrography, whatever, chernobyl, turing, consultations, muluzi,
# Nearest to older: ricimer, calderas, amazon, disintegration, daydream, ld, corda, abunda,
# Nearest to placed: unicorns, geocaching, quincy, indulged, descending, chemically, dangerous, speaker,
# Nearest to arts: hif, saintly, roderick, button, beating, acknowledging, kamikaze, enactments,
# Nearest to alternative: swept, mellotron, forgetting, lzw, scooby, sci, kemerovo, spike,
# Nearest to smith: downrock, clutter, olissipo, advisor, odos, pheasants, wants, iix,
# Nearest to shown: sampled, tetralogy, dreamy, varied, senussi, unaids, basenjis, fairies,
# Epoch 10/10 Iteration: 43100 Avg. Training loss: 3.7654 0.4543 sec/batch
# Epoch 10/10 Iteration: 43200 Avg. Training loss: 3.8398 0.6158 sec/batch
# Epoch 10/10 Iteration: 43300 Avg. Training loss: 3.8799 0.8297 sec/batch
# Epoch 10/10 Iteration: 43400 Avg. Training loss: 3.8484 0.7609 sec/batch
# Epoch 10/10 Iteration: 43500 Avg. Training loss: 3.8273 0.7747 sec/batch
# Epoch 10/10 Iteration: 43600 Avg. Training loss: 3.9251 0.7858 sec/batch
# Epoch 10/10 Iteration: 43700 Avg. Training loss: 3.8625 0.6842 sec/batch
# Epoch 10/10 Iteration: 43800 Avg. Training loss: 3.8246 0.5402 sec/batch
# Epoch 10/10 Iteration: 43900 Avg. Training loss: 3.8638 0.4037 sec/batch
# Epoch 10/10 Iteration: 44000 Avg. Training loss: 3.8298 0.4241 sec/batch
# Nearest to had: dtt, appice, mole, radionuclides, ra, splits, wd, bouldering,
# Nearest to states: aesthetic, xxxxx, forfeit, quaternions, kalmykia, consortium, attorney, cringely,
# Nearest to during: serum, opanal, caravans, manifestly, literati, certified, edwina, purim,
# Nearest to were: neologism, dolphins, gpcrs, differ, entirely, keanu, fashion, presidium,
# Nearest to such: barbican, hydrosphere, fellin, cadavers, executives, pope, pathologies, incongruous,
# Nearest to be: freefall, peaches, embarrassed, vouli, alexandra, alai, macedonian, heaviest,
# Nearest to seven: jornal, store, sowing, licence, oktoberfest, ellison, berwick, vj,
# Nearest to it: dodi, described, flannery, checklist, dedham, terre, journal, ist,
# Nearest to woman: vermont, musk, mohel, lamenting, hurling, razzie, rivera, skins,
# Nearest to dr: haitham, domini, hydrography, whatever, chernobyl, turing, consultations, muluzi,
# Nearest to older: ricimer, calderas, amazon, disintegration, daydream, ld, corda, abunda,
# Nearest to placed: unicorns, geocaching, quincy, indulged, descending, chemically, dangerous, speaker,
# Nearest to arts: hif, saintly, roderick, button, beating, acknowledging, kamikaze, enactments,
# Nearest to alternative: swept, mellotron, forgetting, lzw, scooby, sci, kemerovo, spike,
# Nearest to smith: downrock, clutter, olissipo, advisor, odos, pheasants, wants, iix,
# Nearest to shown: sampled, tetralogy, dreamy, varied, senussi, unaids, basenjis, fairies,
# Epoch 10/10 Iteration: 44100 Avg. Training loss: 3.9051 0.4809 sec/batch
# Epoch 10/10 Iteration: 44200 Avg. Training loss: 3.8746 0.5454 sec/batch
# Epoch 10/10 Iteration: 44300 Avg. Training loss: 3.8246 1.0532 sec/batch
# Epoch 10/10 Iteration: 44400 Avg. Training loss: 3.8831 0.6106 sec/batch
# Epoch 10/10 Iteration: 44500 Avg. Training loss: 3.8578 0.5508 sec/batch
# Epoch 10/10 Iteration: 44600 Avg. Training loss: 3.8590 0.4438 sec/batch
# Epoch 10/10 Iteration: 44700 Avg. Training loss: 3.8605 0.4142 sec/batch
# Epoch 10/10 Iteration: 44800 Avg. Training loss: 3.8569 0.4190 sec/batch
# Epoch 10/10 Iteration: 44900 Avg. Training loss: 3.8394 0.4270 sec/batch
# Epoch 10/10 Iteration: 45000 Avg. Training loss: 3.8482 0.5618 sec/batch
# Nearest to had: dtt, appice, mole, radionuclides, ra, splits, wd, bouldering,
# Nearest to states: aesthetic, xxxxx, forfeit, quaternions, kalmykia, consortium, attorney, cringely,
# Nearest to during: serum, opanal, caravans, manifestly, literati, certified, edwina, purim,
# Nearest to were: neologism, dolphins, gpcrs, differ, entirely, keanu, fashion, presidium,
# Nearest to such: barbican, hydrosphere, fellin, cadavers, executives, pope, pathologies, incongruous,
# Nearest to be: freefall, peaches, embarrassed, vouli, alexandra, alai, macedonian, heaviest,
# Nearest to seven: jornal, store, sowing, licence, oktoberfest, ellison, berwick, vj,
# Nearest to it: dodi, described, flannery, checklist, dedham, terre, journal, ist,
# Nearest to woman: vermont, musk, mohel, lamenting, hurling, razzie, rivera, skins,
# Nearest to dr: haitham, domini, hydrography, whatever, chernobyl, turing, consultations, muluzi,
# Nearest to older: ricimer, calderas, amazon, disintegration, daydream, ld, corda, abunda,
# Nearest to placed: unicorns, geocaching, quincy, indulged, descending, chemically, dangerous, speaker,
# Nearest to arts: hif, saintly, roderick, button, beating, acknowledging, kamikaze, enactments,
# Nearest to alternative: swept, mellotron, forgetting, lzw, scooby, sci, kemerovo, spike,
# Nearest to smith: downrock, clutter, olissipo, advisor, odos, pheasants, wants, iix,
# Nearest to shown: sampled, tetralogy, dreamy, varied, senussi, unaids, basenjis, fairies,
# Epoch 10/10 Iteration: 45100 Avg. Training loss: 3.8642 0.4212 sec/batch
# Epoch 10/10 Iteration: 45200 Avg. Training loss: 3.8425 0.3944 sec/batch
# Epoch 10/10 Iteration: 45300 Avg. Training loss: 3.9349 0.4074 sec/batch
# Epoch 10/10 Iteration: 45400 Avg. Training loss: 3.9358 0.4094 sec/batch
# Epoch 10/10 Iteration: 45500 Avg. Training loss: 3.8860 0.4027 sec/batch
# Epoch 10/10 Iteration: 45600 Avg. Training loss: 3.8528 0.3962 sec/batch
# Epoch 10/10 Iteration: 45700 Avg. Training loss: 3.8050 0.4146 sec/batch
# Epoch 10/10 Iteration: 45800 Avg. Training loss: 3.8622 0.4107 sec/batch
# Epoch 10/10 Iteration: 45900 Avg. Training loss: 3.7729 0.4029 sec/batch
# Epoch 10/10 Iteration: 46000 Avg. Training loss: 3.8707 0.4467 sec/batch
# Nearest to had: dtt, appice, mole, radionuclides, ra, splits, wd, bouldering,
# Nearest to states: aesthetic, xxxxx, forfeit, quaternions, kalmykia, consortium, attorney, cringely,
# Nearest to during: serum, opanal, caravans, manifestly, literati, certified, edwina, purim,
# Nearest to were: neologism, dolphins, gpcrs, differ, entirely, keanu, fashion, presidium,
# Nearest to such: barbican, hydrosphere, fellin, cadavers, executives, pope, pathologies, incongruous,
# Nearest to be: freefall, peaches, embarrassed, vouli, alexandra, alai, macedonian, heaviest,
# Nearest to seven: jornal, store, sowing, licence, oktoberfest, ellison, berwick, vj,
# Nearest to it: dodi, described, flannery, checklist, dedham, terre, journal, ist,
# Nearest to woman: vermont, musk, mohel, lamenting, hurling, razzie, rivera, skins,
# Nearest to dr: haitham, domini, hydrography, whatever, chernobyl, turing, consultations, muluzi,
# Nearest to older: ricimer, calderas, amazon, disintegration, daydream, ld, corda, abunda,
# Nearest to placed: unicorns, geocaching, quincy, indulged, descending, chemically, dangerous, speaker,
# Nearest to arts: hif, saintly, roderick, button, beating, acknowledging, kamikaze, enactments,
# Nearest to alternative: swept, mellotron, forgetting, lzw, scooby, sci, kemerovo, spike,
# Nearest to smith: downrock, clutter, olissipo, advisor, odos, pheasants, wants, iix,
# Nearest to shown: sampled, tetralogy, dreamy, varied, senussi, unaids, basenjis, fairies,
# Epoch 10/10 Iteration: 46100 Avg. Training loss: 3.8845 0.4109 sec/batch
# Epoch 10/10 Iteration: 46200 Avg. Training loss: 3.8531 0.4140 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints/text8.ckpt

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
